# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv(r"C:\Users\Priyansh Singh\Desktop\Job Market\data\processed\jobs_for_analysis.csv")

# %%
cols_to_drop = ["job_id", "source", "url", "job_numeric_id"]
df = df.drop(columns=cols_to_drop, errors="ignore")

# %%
df
# Out:
#                                                   title  \
# 0     data analyst  predictive analytics  india  x d...
# 1                                  data analyst trainee
# 2     sr. data analyst  adtech/omnichannel  remote  ...
# 3               data analyst   ecommerce & d2c insights
# 4                          senior data analyst payments
# ...                                                 ...
# 1382                 data engineer python pyspark panda
# 1383                           lead  tech  python infra
# 1384                            senior python developer
# 1385                      python developer with dagster
# 1386                        python developer with azure
#
#                                     company posted_date employment_type  \
# 0                   Boston Consulting Group  2025-12-01       full-time
# 1                    SparkNovaTechSolutions  2025-12-02       full-time
# 2                                 Jobgether  2025-12-01       full-time
# 3     Wholsum Foods (Slurrp Farm and Mille)  2025-12-02       full-time
# 4                                      Roku         NaN       full-time
# ...                                     ...         ...             ...
# 1382                            LTIMindtree  2025-12-01       full-time
# 1383                       D. E. Shaw India  2025-12-03       full-time
# 1384                                 Luxoft  2025-11-30       full-time
# 1385                     Staffington Global  2025-11-25       full-time
# 1386                 People Prime Worldwide  2025-11-28       full-time
#
#                                             description  salary_avg  \
# 0     Locations: Bengaluru | Gurgaon\n\nWho We Are\n...         3.0
# 1     ABOUT THE ROLE\n\nWe are seeking a highly moti...         7.0
# 2     Sr. Data Analyst, AdTech/Omnichannel (Remote, ...         1.0
# 3     Job Description: Data Analyst - Ecommerce & D2...         4.5
# 4     Teamwork makes the stream work.\n\nRoku is cha...         1.0
# ...                                                 ...         ...
# 1382  **Role Overview:**\n\nAs a Data Engineer with ...         7.5
# 1383  We are looking for a Software Developer to joi...         7.0
# 1384  Project description\n\nWe're seeking a strong ...         6.0
# 1385  Job Description:-\n\nJob Role: Python Develope...         5.0
# 1386  You are a skilled and motivated Python Develop...         9.0
#
#            city seniority_level  \
# 0      Gurugram             mid
# 1        Jaipur             mid
# 2            IN          senior
# 3      Gurugram             mid
# 4     Bengaluru          senior
# ...         ...             ...
# 1382  Hyderabad             mid
# 1383  Hyderabad            lead
# 1384  Hyderabad          senior
# 1385  Hyderabad             mid
# 1386  Hyderabad             mid
#
#                                              clean_role
# 0                      analytics engineer, data analyst
# 1     ai engineer, analytics engineer, data analyst,...
# 2                      analytics engineer, data analyst
# 3                      analytics engineer, data analyst
# 4                      analytics engineer, data analyst
# ...                                                 ...
# 1382                                      data engineer
# 1383                                              other
# 1384                                   python developer
# 1385                                   python developer
# 1386                                   python developer
#
# [1387 rows x 9 columns]

# %%
def clean_title_func(text: str) -> str:
    if pd.isna(text):
        return ""
    t = str(text).lower()
    # normalize common seniority abbreviations
    t = t.replace("sr.", " senior ")
    t = t.replace("sr ", " senior ")
    t = t.replace("jr.", " junior ")
    t = t.replace("jr ", " junior ")
    
    # remove common noise words that look like location / channel / misc
    remove_words = [
        "india", "remote", "hybrid", "x delivery", "delivery",
        "adtech", "omnichannel", "ecommerce", "insights"
    ]
    for w in remove_words:
        t = t.replace(w, " ")
    
    # collapse spaces
    t = " ".join(t.split())
    # Title case
    return t.title()

df["clean_title"] = df["title"].astype(str).apply(clean_title_func)

# %%
df
# Out:
#                                                   title  \
# 0     data analyst  predictive analytics  india  x d...
# 1                                  data analyst trainee
# 2     sr. data analyst  adtech/omnichannel  remote  ...
# 3               data analyst   ecommerce & d2c insights
# 4                          senior data analyst payments
# ...                                                 ...
# 1382                 data engineer python pyspark panda
# 1383                           lead  tech  python infra
# 1384                            senior python developer
# 1385                      python developer with dagster
# 1386                        python developer with azure
#
#                                     company posted_date employment_type  \
# 0                   Boston Consulting Group  2025-12-01       full-time
# 1                    SparkNovaTechSolutions  2025-12-02       full-time
# 2                                 Jobgether  2025-12-01       full-time
# 3     Wholsum Foods (Slurrp Farm and Mille)  2025-12-02       full-time
# 4                                      Roku         NaN       full-time
# ...                                     ...         ...             ...
# 1382                            LTIMindtree  2025-12-01       full-time
# 1383                       D. E. Shaw India  2025-12-03       full-time
# 1384                                 Luxoft  2025-11-30       full-time
# 1385                     Staffington Global  2025-11-25       full-time
# 1386                 People Prime Worldwide  2025-11-28       full-time
#
#                                             description  salary_avg  \
# 0     Locations: Bengaluru | Gurgaon\n\nWho We Are\n...         3.0
# 1     ABOUT THE ROLE\n\nWe are seeking a highly moti...         7.0
# 2     Sr. Data Analyst, AdTech/Omnichannel (Remote, ...         1.0
# 3     Job Description: Data Analyst - Ecommerce & D2...         4.5
# 4     Teamwork makes the stream work.\n\nRoku is cha...         1.0
# ...                                                 ...         ...
# 1382  **Role Overview:**\n\nAs a Data Engineer with ...         7.5
# 1383  We are looking for a Software Developer to joi...         7.0
# 1384  Project description\n\nWe're seeking a strong ...         6.0
# 1385  Job Description:-\n\nJob Role: Python Develope...         5.0
# 1386  You are a skilled and motivated Python Develop...         9.0
#
#            city seniority_level  \
# 0      Gurugram             mid
# 1        Jaipur             mid
# 2            IN          senior
# 3      Gurugram             mid
# 4     Bengaluru          senior
# ...         ...             ...
# 1382  Hyderabad             mid
# 1383  Hyderabad            lead
# 1384  Hyderabad          senior
# 1385  Hyderabad             mid
# 1386  Hyderabad             mid
#
#                                              clean_role  \
# 0                      analytics engineer, data analyst
# 1     ai engineer, analytics engineer, data analyst,...
# 2                      analytics engineer, data analyst
# 3                      analytics engineer, data analyst
# 4                      analytics engineer, data analyst
# ...                                                 ...
# 1382                                      data engineer
# 1383                                              other
# 1384                                   python developer
# 1385                                   python developer
# 1386                                   python developer
#
#                              clean_title
# 0      Data Analyst Predictive Analytics
# 1                   Data Analyst Trainee
# 2                  Senior Data Analyst /
# 3                     Data Analyst & D2C
# 4           Senior Data Analyst Payments
# ...                                  ...
# 1382  Data Engineer Python Pyspark Panda
# 1383              Lead Tech Python Infra
# 1384             Senior Python Developer
# 1385       Python Developer With Dagster
# 1386         Python Developer With Azure
#
# [1387 rows x 10 columns]

# %%
def clean_location_func(text: str) -> str:
    if pd.isna(text):
        return ""
    t = str(text).strip()
    t_low = t.lower()
    # normalize remote formats
    if "remote" in t_low:
        return "Remote"
    return t.title()

df["clean_location"] = df["city"].astype(str).apply(clean_location_func)

# %%
df
# Out:
#                                                   title  \
# 0     data analyst  predictive analytics  india  x d...
# 1                                  data analyst trainee
# 2     sr. data analyst  adtech/omnichannel  remote  ...
# 3               data analyst   ecommerce & d2c insights
# 4                          senior data analyst payments
# ...                                                 ...
# 1382                 data engineer python pyspark panda
# 1383                           lead  tech  python infra
# 1384                            senior python developer
# 1385                      python developer with dagster
# 1386                        python developer with azure
#
#                                     company posted_date employment_type  \
# 0                   Boston Consulting Group  2025-12-01       full-time
# 1                    SparkNovaTechSolutions  2025-12-02       full-time
# 2                                 Jobgether  2025-12-01       full-time
# 3     Wholsum Foods (Slurrp Farm and Mille)  2025-12-02       full-time
# 4                                      Roku         NaN       full-time
# ...                                     ...         ...             ...
# 1382                            LTIMindtree  2025-12-01       full-time
# 1383                       D. E. Shaw India  2025-12-03       full-time
# 1384                                 Luxoft  2025-11-30       full-time
# 1385                     Staffington Global  2025-11-25       full-time
# 1386                 People Prime Worldwide  2025-11-28       full-time
#
#                                             description  salary_avg  \
# 0     Locations: Bengaluru | Gurgaon\n\nWho We Are\n...         3.0
# 1     ABOUT THE ROLE\n\nWe are seeking a highly moti...         7.0
# 2     Sr. Data Analyst, AdTech/Omnichannel (Remote, ...         1.0
# 3     Job Description: Data Analyst - Ecommerce & D2...         4.5
# 4     Teamwork makes the stream work.\n\nRoku is cha...         1.0
# ...                                                 ...         ...
# 1382  **Role Overview:**\n\nAs a Data Engineer with ...         7.5
# 1383  We are looking for a Software Developer to joi...         7.0
# 1384  Project description\n\nWe're seeking a strong ...         6.0
# 1385  Job Description:-\n\nJob Role: Python Develope...         5.0
# 1386  You are a skilled and motivated Python Develop...         9.0
#
#            city seniority_level  \
# 0      Gurugram             mid
# 1        Jaipur             mid
# 2            IN          senior
# 3      Gurugram             mid
# 4     Bengaluru          senior
# ...         ...             ...
# 1382  Hyderabad             mid
# 1383  Hyderabad            lead
# 1384  Hyderabad          senior
# 1385  Hyderabad             mid
# 1386  Hyderabad             mid
#
#                                              clean_role  \
# 0                      analytics engineer, data analyst
# 1     ai engineer, analytics engineer, data analyst,...
# 2                      analytics engineer, data analyst
# 3                      analytics engineer, data analyst
# 4                      analytics engineer, data analyst
# ...                                                 ...
# 1382                                      data engineer
# 1383                                              other
# 1384                                   python developer
# 1385                                   python developer
# 1386                                   python developer
#
#                              clean_title clean_location
# 0      Data Analyst Predictive Analytics       Gurugram
# 1                   Data Analyst Trainee         Jaipur
# 2                  Senior Data Analyst /             In
# 3                     Data Analyst & D2C       Gurugram
# 4           Senior Data Analyst Payments      Bengaluru
# ...                                  ...            ...
# 1382  Data Engineer Python Pyspark Panda      Hyderabad
# 1383              Lead Tech Python Infra      Hyderabad
# 1384             Senior Python Developer      Hyderabad
# 1385       Python Developer With Dagster      Hyderabad
# 1386         Python Developer With Azure      Hyderabad
#
# [1387 rows x 11 columns]

# %%
def infer_seniority(row) -> str:
    s = str(row.get("seniority_level", "")).lower()
    t = str(row.get("title", "")).lower()
    combined = s + " " + t
    
    if any(x in combined for x in ["lead", "principal", "senior"]):
        return "senior"
    if any(x in combined for x in ["junior", "intern", "trainee", "fresher"]):
        return "junior"
    return "mid"

df["clean_seniority"] = df.apply(infer_seniority, axis=1)

# %%
df
# Out:
#                                                   title  \
# 0     data analyst  predictive analytics  india  x d...
# 1                                  data analyst trainee
# 2     sr. data analyst  adtech/omnichannel  remote  ...
# 3               data analyst   ecommerce & d2c insights
# 4                          senior data analyst payments
# ...                                                 ...
# 1382                 data engineer python pyspark panda
# 1383                           lead  tech  python infra
# 1384                            senior python developer
# 1385                      python developer with dagster
# 1386                        python developer with azure
#
#                                     company posted_date employment_type  \
# 0                   Boston Consulting Group  2025-12-01       full-time
# 1                    SparkNovaTechSolutions  2025-12-02       full-time
# 2                                 Jobgether  2025-12-01       full-time
# 3     Wholsum Foods (Slurrp Farm and Mille)  2025-12-02       full-time
# 4                                      Roku         NaN       full-time
# ...                                     ...         ...             ...
# 1382                            LTIMindtree  2025-12-01       full-time
# 1383                       D. E. Shaw India  2025-12-03       full-time
# 1384                                 Luxoft  2025-11-30       full-time
# 1385                     Staffington Global  2025-11-25       full-time
# 1386                 People Prime Worldwide  2025-11-28       full-time
#
#                                             description  salary_avg  \
# 0     Locations: Bengaluru | Gurgaon\n\nWho We Are\n...         3.0
# 1     ABOUT THE ROLE\n\nWe are seeking a highly moti...         7.0
# 2     Sr. Data Analyst, AdTech/Omnichannel (Remote, ...         1.0
# 3     Job Description: Data Analyst - Ecommerce & D2...         4.5
# 4     Teamwork makes the stream work.\n\nRoku is cha...         1.0
# ...                                                 ...         ...
# 1382  **Role Overview:**\n\nAs a Data Engineer with ...         7.5
# 1383  We are looking for a Software Developer to joi...         7.0
# 1384  Project description\n\nWe're seeking a strong ...         6.0
# 1385  Job Description:-\n\nJob Role: Python Develope...         5.0
# 1386  You are a skilled and motivated Python Develop...         9.0
#
#            city seniority_level  \
# 0      Gurugram             mid
# 1        Jaipur             mid
# 2            IN          senior
# 3      Gurugram             mid
# 4     Bengaluru          senior
# ...         ...             ...
# 1382  Hyderabad             mid
# 1383  Hyderabad            lead
# 1384  Hyderabad          senior
# 1385  Hyderabad             mid
# 1386  Hyderabad             mid
#
#                                              clean_role  \
# 0                      analytics engineer, data analyst
# 1     ai engineer, analytics engineer, data analyst,...
# 2                      analytics engineer, data analyst
# 3                      analytics engineer, data analyst
# 4                      analytics engineer, data analyst
# ...                                                 ...
# 1382                                      data engineer
# 1383                                              other
# 1384                                   python developer
# 1385                                   python developer
# 1386                                   python developer
#
#                              clean_title clean_location clean_seniority
# 0      Data Analyst Predictive Analytics       Gurugram             mid
# 1                   Data Analyst Trainee         Jaipur          junior
# 2                  Senior Data Analyst /             In          senior
# 3                     Data Analyst & D2C       Gurugram             mid
# 4           Senior Data Analyst Payments      Bengaluru          senior
# ...                                  ...            ...             ...
# 1382  Data Engineer Python Pyspark Panda      Hyderabad             mid
# 1383              Lead Tech Python Infra      Hyderabad          senior
# 1384             Senior Python Developer      Hyderabad          senior
# 1385       Python Developer With Dagster      Hyderabad             mid
# 1386         Python Developer With Azure      Hyderabad             mid
#
# [1387 rows x 12 columns]

# %%
df.to_csv("jobs_for_model.csv", index=False)
print("Saved jobs_for_model.csv")
# Out:
# Saved jobs_for_model.csv
